# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import*

class Tracker:
    def __init__(self):
        # Store the center positions of the objects
        self.center_points = {}
        # Keep the count of the IDs
        # each time a new object id detected, the count will increase by one
        self.id_count = 0

    def update(self, objects_rect):
        # Objects boxes and ids
        objects_bbs_ids = []

        # Get center point of new object
        for rect in objects_rect:
            if len(rect) >= 4:  # Ensure rect has at least 4 values (x, y, w, h)
                x, y, w, h = rect[:4]  # Extract only the first 4 values
                cx = (x + x + w) // 2
                cy = (y + y + h) // 2

                # Find out if that object was detected already
                same_object_detected = False
                for id, pt in self.center_points.items():
                    dist = math.hypot(cx - pt[0], cy - pt[1])

                    if dist < 35:
                        self.center_points[id] = (cx, cy)
                        objects_bbs_ids.append([x, y, w, h, id])
                        same_object_detected = True
                        break

                # New object is detected we assign the ID to that object
                if not same_object_detected:
                    self.center_points[self.id_count] = (cx, cy)
                    objects_bbs_ids.append([x, y, w, h, self.id_count])
                    self.id_count += 1

        # Clean the dictionary by center points to remove IDs not used anymore
        new_center_points = {}
        for obj_bb_id in objects_bbs_ids:
            _, _, _, _, object_id = obj_bb_id
            center = self.center_points[object_id]
            new_center_points[object_id] = center

        # Update dictionary with IDs not used removed
        self.center_points = new_center_points.copy()
        return objects_bbs_ids

model = YOLO('yolov9c.pt')

class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

tracker = Tracker()
count = 0

cap = cv2.VideoCapture('trial2.mp4') 

down = {}
counter_down = set()
while True:    
    ret, frame = cap.read()
    if not ret:
        break
    count += 1

    results = model.predict(frame)

    a = results[0].boxes.data
    a = a.detach().cpu().numpy()  
    px = pd.DataFrame(a).astype("float")
    
    list = []
             
    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        if 'car' in c:
            list.append([x1, y1, x2, y2])

    bbox_id = tracker.update(list)
    
    for bbox in bbox_id:
        x1, y1, x2, y2, id = bbox
        cx = (x1 + x2) // 2
        cy = (y1 + y2) // 2
        cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)  # Draw center points of bounding box
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Draw bounding box
        cv2.putText(frame, str(id), (cx, cy), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

        y = 308
        offset = 7

        ''' condition for red line '''
        if y < (cy + offset) and y > (cy - offset):
            down[id] = cy   # Save the IDs of the cars which are touching the red line first
            counter_down.add(id) 

    text_color = (255, 255, 255)  # White color for text
    red_color = (0, 0, 255)  # (B, G, R)   

    cv2.line(frame, (282, 308), (1004, 308), red_color, 3)  # Draw red line
    cv2.putText(frame, 'red line', (280, 308), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA) 

    downwards = len(counter_down)
    cv2.putText(frame, 'going down - ' + str(downwards), (60, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, red_color, 1, cv2.LINE_AA) 

    cv2.imshow("frames", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 persons, 12 cars, 2 motorcycles, 4 buss, 12 trucks, 1 umbrella, 2198.4ms
# Speed: 15.0ms preprocess, 2198.4ms inference, 23.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 12 cars, 2 motorcycles, 4 buss, 12 trucks, 1 umbrella, 1986.1ms
# Speed: 17.5ms preprocess, 1986.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 3 motorcycles, 6 buss, 11 trucks, 1 umbrella, 1226.9ms
# Speed: 9.0ms preprocess, 1226.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 2 motorcycles, 3 buss, 13 trucks, 1 umbrella, 585.0ms
# Speed: 4.0ms preprocess, 585.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 cars, 2 motorcycles, 3 buss, 13 trucks, 1 umbrella, 582.3ms
# Speed: 0.0ms preprocess, 582.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 12 cars, 2 motorcycles, 4 buss, 12 trucks, 1 umbrella, 647.0ms
# Speed: 0.0ms preprocess, 647.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 13 cars, 3 motorcycles, 4 buss, 10 trucks, 1 umbrella, 558.5ms
# Speed: 2.9ms preprocess, 558.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 13 cars, 2 motorcycles, 4 buss, 12 trucks, 1 umbrella, 604.4ms
# Speed: 0.0ms preprocess, 604.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 13 cars, 2 motorcycles, 5 buss, 11 trucks, 1 umbrella, 672.9ms
# Speed: 0.0ms preprocess, 672.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 cars, 2 motorcycles, 5 buss, 14 trucks, 1 umbrella, 641.5ms
# Speed: 0.0ms preprocess, 641.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 12 cars, 3 motorcycles, 4 buss, 16 trucks, 1 umbrella, 641.6ms
# Speed: 0.0ms preprocess, 641.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 cars, 3 motorcycles, 4 buss, 15 trucks, 1 umbrella, 657.0ms
# Speed: 0.0ms preprocess, 657.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14 cars, 3 motorcycles, 5 buss, 13 trucks, 1 umbrella, 656.9ms
# Speed: 0.0ms preprocess, 656.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 14 cars, 2 motorcycles, 3 buss, 10 trucks, 1 umbrella, 657.0ms
# Speed: 0.0ms preprocess, 657.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 16 cars, 2 motorcycles, 3 buss, 12 trucks, 1 umbrella, 670.6ms
# Speed: 1.1ms preprocess, 670.6ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 16 cars, 2 motorcycles, 5 buss, 11 trucks, 1 umbrella, 656.8ms
# Speed: 0.0ms preprocess, 656.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 16 cars, 2 motorcycles, 4 buss, 10 trucks, 1 umbrella, 658.3ms
# Speed: 15.6ms preprocess, 658.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15 cars, 3 motorcycles, 4 buss, 12 trucks, 1 umbrella, 678.8ms
# Speed: 2.1ms preprocess, 678.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 13 cars, 3 motorcycles, 5 buss, 10 trucks, 656.4ms
# Speed: 0.0ms preprocess, 656.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 15 cars, 2 motorcycles, 5 buss, 9 trucks, 705.4ms
# Speed: 0.0ms preprocess, 705.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 15 cars, 2 motorcycles, 5 buss, 9 trucks, 704.1ms
# Speed: 0.0ms preprocess, 704.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 13 cars, 3 motorcycles, 5 buss, 10 trucks, 641.0ms
# Speed: 15.6ms preprocess, 641.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14 cars, 2 motorcycles, 5 buss, 9 trucks, 516.3ms
# Speed: 0.0ms preprocess, 516.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 3 motorcycles, 5 buss, 12 trucks, 1 umbrella, 578.1ms
# Speed: 0.0ms preprocess, 578.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14 cars, 2 motorcycles, 5 buss, 10 trucks, 1 umbrella, 672.4ms
# Speed: 0.0ms preprocess, 672.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 13 cars, 1 motorcycle, 5 buss, 9 trucks, 1 umbrella, 621.1ms
# Speed: 1.1ms preprocess, 621.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15 cars, 1 motorcycle, 6 buss, 9 trucks, 1 umbrella, 625.0ms
# Speed: 0.0ms preprocess, 625.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 15 cars, 1 motorcycle, 4 buss, 9 trucks, 1 umbrella, 692.5ms
# Speed: 0.0ms preprocess, 692.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15 cars, 1 motorcycle, 4 buss, 10 trucks, 1 umbrella, 672.5ms
# Speed: 0.0ms preprocess, 672.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 17 cars, 1 motorcycle, 5 buss, 10 trucks, 1 umbrella, 687.7ms
# Speed: 0.0ms preprocess, 687.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 1 motorcycle, 5 buss, 10 trucks, 1 umbrella, 586.0ms
# Speed: 8.6ms preprocess, 586.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 14 cars, 1 motorcycle, 6 buss, 10 trucks, 1 umbrella, 719.1ms
# Speed: 0.0ms preprocess, 719.1ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 16 cars, 5 buss, 9 trucks, 1 umbrella, 697.1ms
# Speed: 1.0ms preprocess, 697.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 16 cars, 1 motorcycle, 6 buss, 8 trucks, 1 umbrella, 703.3ms
# Speed: 15.6ms preprocess, 703.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 15 cars, 5 buss, 10 trucks, 1 umbrella, 687.7ms
# Speed: 0.0ms preprocess, 687.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 3 buss, 11 trucks, 709.9ms
# Speed: 0.0ms preprocess, 709.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 15 cars, 4 buss, 11 trucks, 688.0ms
# Speed: 0.0ms preprocess, 688.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 5 buss, 12 trucks, 687.5ms
# Speed: 0.0ms preprocess, 687.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 4 buss, 11 trucks, 578.3ms
# Speed: 15.6ms preprocess, 578.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 4 buss, 12 trucks, 579.5ms
# Speed: 0.0ms preprocess, 579.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 4 buss, 11 trucks, 614.9ms
# Speed: 2.1ms preprocess, 614.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 16 cars, 4 buss, 9 trucks, 625.6ms
# Speed: 0.0ms preprocess, 625.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17 cars, 4 buss, 11 trucks, 1 umbrella, 672.4ms
# Speed: 0.0ms preprocess, 672.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16 cars, 4 buss, 13 trucks, 672.1ms
# Speed: 0.0ms preprocess, 672.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 1 motorcycle, 3 buss, 9 trucks, 1 umbrella, 656.2ms
# Speed: 15.7ms preprocess, 656.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 16 cars, 3 buss, 9 trucks, 1 umbrella, 616.6ms
# Speed: 1.0ms preprocess, 616.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 2 buss, 11 trucks, 703.1ms
# Speed: 0.0ms preprocess, 703.1ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 persons, 17 cars, 1 motorcycle, 2 buss, 10 trucks, 1 umbrella, 688.4ms
# Speed: 0.0ms preprocess, 688.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 18 cars, 2 motorcycles, 4 buss, 9 trucks, 1 umbrella, 640.6ms
# Speed: 0.0ms preprocess, 640.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17 cars, 1 motorcycle, 5 buss, 8 trucks, 1 umbrella, 562.0ms
# Speed: 2.1ms preprocess, 562.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17 cars, 1 motorcycle, 5 buss, 9 trucks, 1 umbrella, 672.5ms
# Speed: 0.0ms preprocess, 672.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17 cars, 1 motorcycle, 4 buss, 8 trucks, 1 umbrella, 609.5ms
# Speed: 15.6ms preprocess, 609.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17 cars, 1 motorcycle, 2 buss, 10 trucks, 1 umbrella, 632.4ms
# Speed: 2.1ms preprocess, 632.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 2 buss, 9 trucks, 1 umbrella, 578.4ms
# Speed: 0.0ms preprocess, 578.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 18 cars, 2 buss, 11 trucks, 1 umbrella, 562.7ms
# Speed: 0.0ms preprocess, 562.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 2 buss, 8 trucks, 1 umbrella, 516.6ms
# Speed: 0.0ms preprocess, 516.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 18 cars, 1 motorcycle, 2 buss, 8 trucks, 1 umbrella, 547.6ms
# Speed: 0.0ms preprocess, 547.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17 cars, 3 buss, 5 trucks, 1 umbrella, 547.7ms
# Speed: 0.0ms preprocess, 547.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 17 cars, 3 buss, 6 trucks, 1 umbrella, 673.1ms
# Speed: 0.0ms preprocess, 673.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 18 cars, 1 motorcycle, 3 buss, 8 trucks, 1 umbrella, 672.3ms
# Speed: 0.0ms preprocess, 672.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 18 cars, 1 motorcycle, 3 buss, 8 trucks, 1 umbrella, 609.9ms
# Speed: 1.5ms preprocess, 609.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 18 cars, 2 motorcycles, 3 buss, 7 trucks, 1 umbrella, 594.3ms
# Speed: 0.0ms preprocess, 594.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 2 motorcycles, 2 buss, 8 trucks, 1 umbrella, 610.2ms
# Speed: 0.0ms preprocess, 610.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 2 motorcycles, 2 buss, 9 trucks, 1 umbrella, 658.1ms
# Speed: 0.0ms preprocess, 658.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 1 motorcycle, 3 buss, 7 trucks, 1 umbrella, 672.2ms
# Speed: 0.0ms preprocess, 672.2ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 2 motorcycles, 2 buss, 6 trucks, 1 umbrella, 656.8ms
# Speed: 0.0ms preprocess, 656.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 18 cars, 2 motorcycles, 4 buss, 7 trucks, 1 umbrella, 687.8ms
# Speed: 0.0ms preprocess, 687.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 16 cars, 3 motorcycles, 3 buss, 6 trucks, 1 umbrella, 687.8ms
# Speed: 0.0ms preprocess, 687.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 18 cars, 3 motorcycles, 3 buss, 8 trucks, 1 umbrella, 630.0ms
# Speed: 1.0ms preprocess, 630.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16 cars, 2 motorcycles, 3 buss, 7 trucks, 1 umbrella, 687.6ms
# Speed: 0.0ms preprocess, 687.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 2 motorcycles, 3 buss, 7 trucks, 1 umbrella, 562.9ms
# Speed: 0.0ms preprocess, 562.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 3 motorcycles, 3 buss, 10 trucks, 1 umbrella, 666.6ms
# Speed: 0.0ms preprocess, 666.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 19 cars, 2 motorcycles, 3 buss, 9 trucks, 1 umbrella, 457.1ms
# Speed: 0.0ms preprocess, 457.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 17 cars, 2 motorcycles, 3 buss, 13 trucks, 1 umbrella, 563.3ms
# Speed: 0.0ms preprocess, 563.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 17 cars, 2 motorcycles, 3 buss, 10 trucks, 1 umbrella, 594.7ms
# Speed: 0.0ms preprocess, 594.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 18 cars, 2 motorcycles, 2 buss, 10 trucks, 1 umbrella, 628.1ms
# Speed: 2.1ms preprocess, 628.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 2 motorcycles, 3 buss, 11 trucks, 1 umbrella, 703.7ms
# Speed: 0.0ms preprocess, 703.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 2 motorcycles, 3 buss, 11 trucks, 1 umbrella, 682.1ms
# Speed: 7.7ms preprocess, 682.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 2 motorcycles, 2 buss, 12 trucks, 1 umbrella, 720.9ms
# Speed: 8.6ms preprocess, 720.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 17 cars, 2 motorcycles, 3 buss, 9 trucks, 1 umbrella, 717.3ms
# Speed: 0.0ms preprocess, 717.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 16 cars, 2 motorcycles, 2 buss, 10 trucks, 1 umbrella, 675.4ms
# Speed: 0.0ms preprocess, 675.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 13 cars, 2 motorcycles, 3 buss, 12 trucks, 1 umbrella, 631.1ms
# Speed: 0.0ms preprocess, 631.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 16 cars, 2 motorcycles, 2 buss, 11 trucks, 1 umbrella, 698.0ms
# Speed: 0.0ms preprocess, 698.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
